# %%
import PIL

# %%
from PIL import Image

# %%
image = Image.open("/Users/urkhan/Downloads/poetry.jpeg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x455 at 0x7FFD7CF75D60>

# %%
import pytesseract

# %%
dir(pytesseract)
# Out:
# ['ALTONotSupported',
#  'Output',
#  'TSVNotSupported',
#  'TesseractError',
#  'TesseractNotFoundError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'get_languages',
#  'get_tesseract_version',
#  'image_to_alto_xml',
#  'image_to_boxes',
#  'image_to_data',
#  'image_to_osd',
#  'image_to_pdf_or_hocr',
#  'image_to_string',
#  'pytesseract',
#  'run_and_get_output']

# %%
pytesseract.image_to_string
# Out:
# <function pytesseract.pytesseract.image_to_string(image, lang=None, config='', nice=0, output_type='string', timeout=0)>

# %%
from PIL import Image

# %%
img = Image.open("/Users/urkhan/Downloads/poetry.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x455 at 0x7FFD7CF75E50>

# %%
txt = pytesseract.image_to_string(img)

# %%
print(txt)
# Out:
# There is a pleasure in the pathless woods;
# There is a rapture on the lonely shore;
# There is society, where none intrudes,
# By the deep sea, and music in its roar,
# I love not the man less, but Nature more...
#
# - Lord Byron

# %%
img= Image.open("/users/urkhan/downloads/poetry1.jpeg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=645x401 at 0x7FF521E65DC0>

# %%
txt=pytesseract.image_to_string(img)
print(txt)
# Out:
# There is a pleasure in the pathless woods;
# There is a rapture on the lonely shore;
# There is society, where none intrudes,
# By the deep sea, and music in its roar,
# I love not the man less, but Nature more...
#
# - Lord Byron

# %%
def binarize(image_to_transform,threshold):
    output_image = image_to_transform.convert('L')
    for x in range(output_image.width):
        for y in range(output_image.height):
            if output_image.getpixel((x,y)) < threshold:
                output_image.putpixel((x,y), 0)
            else:
                output_image.putpixel((x,y), 255)
                
    return output_image

for thresh in range(0, 257, 64):
    print("thershold = "+ str(thresh))
    display(binarize(Image.open("/users/urkhan/downloads/poetry1.jpeg"), thresh))
    print(pytesseract.image_to_string(binarize(Image.open('/users/urkhan/downloads/poetry1.jpeg'), thresh)))
# Out:
# thershold = 0
# <PIL.Image.Image image mode=L size=645x401 at 0x7FFD7A071070>
# thershold = 64
# <PIL.Image.Image image mode=L size=645x401 at 0x7FFD7A095F70>
# I was your cure,
# but you were my disease
# I was saving you,
# but you were killing me.
#
# thershold = 128
# <PIL.Image.Image image mode=L size=645x401 at 0x7FFD7CF709D0>
# I was your cure,
# but you were my disease
# I was saving you,
# but you were killing me.
#
# thershold = 192
# <PIL.Image.Image image mode=L size=645x401 at 0x7FFD7A095160>
# I was your cure,
# but you were my disease
# I was saving you,
# but you were killing me.
#
# thershold = 256
# <PIL.Image.Image image mode=L size=645x401 at 0x7FFD7A095160>
