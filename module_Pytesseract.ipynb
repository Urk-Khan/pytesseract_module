# %%
import PIL

# %%
from PIL import Image

# %%
image = Image.open("/Users/urkhan/Downloads/poetry.jpeg")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x455 at 0x7F82C5156DC0>

# %%
import pytesseract
